# %%
#1.Identify and fix the syntax error in the following code:
age = 18
if age >= 18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2.Question:
# What error will occur in the following code?

def greet():
    print("Hello, World!")

greet_user() - nameerror
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 def greet():
#       5     print("Hello, World!")
# ----> 7 greet_user() - nameerror
#
# NameError: name 'greet_user' is not defined

# %%
greet()
# Out:
# Hello, World!

# %%
#3.Identify the error in this code:

name = "Alice"
age = 25
print("My name is " + name + " and I am " + str(age) + " years old.")
# Out:
# My name is Alice and I am 25 years old.

# %%
#4.Question:
#What will happen when you run this code?

a = 10
b = 0
result = a / b
print(result) #division error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 6
#       4 a = 10
#       5 b = 0
# ----> 6 result = a / b
#       7 print(result) #division error
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Division error

# %%
#5.What error will occur in the following code?

num = int("xyz")
print(num)

# %% [markdown]
# typeerror

# %%
#6.Identify the issue in this code:

data = {"name": "John", "age": 30}
print(data["city"])
# Out:
#   Cell In[18], line 4
#     print(data ["city"]="India")
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
#7.What will happen when you run this code?
num = 1
while num < 5:
    print(num)

# %% [markdown]
# if it is true code will run if false means it will stop the loop
# Here it will run the loop

# %%
#8.What is wrong with this code?

fruits = ("apple", "banana", "cherry")
print(fruits[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 #8.What is wrong with this code?
#       3 fruits = ("apple", "banana", "cherry")
# ----> 4 print(fruits[3])
#
# IndexError: tuple index out of range

# %% [markdown]
# There is onlt three elements in the above list but here we are call the position 3rd which is out of range.
# Because the list will start with zero position. i.e, apple is 0, banana is 1, cherrry is 2. so 3 is out of range.

# %%
#9.What will happen when you run this code?

text = "hello world"
text.append("!")

# %% [markdown]
# it will append the "!" with the text so output should be "hello world"

# %%
#10.What is wrong with the following code?

import randoms
print(randoms.randint(1, 10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 #10.What is wrong with the following code?
# ----> 3 import randoms
#       4 print(randoms.randint(1, 10))
#
# ModuleNotFoundError: No module named 'randoms'

# %% [markdown]
# here the module name is mistake.

# %%
import random
print(random.randint(1,10))
# Out:
# 7
